# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/lenovo/Desktop/datasets/train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#shows number of rows and columns
df.shape
# Out:
# (891, 12)

# %%
# showa columns heading
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#checking data 
df[['Embarked','Pclass','Parch']].head(20)
# Out:
#    Embarked  Pclass  Parch
# 0         S       3      0
# 1         C       1      0
# 2         S       3      0
# 3         S       1      0
# 4         S       3      0
# 5         Q       3      0
# 6         S       1      0
# 7         S       3      1
# 8         S       3      2
# 9         C       2      0
# 10        S       3      1
# 11        S       1      0
# 12        S       3      0
# 13        S       3      5
# 14        S       3      0
# 15        S       2      0
# 16        Q       3      1
# 17        S       2      0
# 18        S       3      0
# 19        C       3      0

# %%
#checking null values 
df.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
#columwise total null values
print(pd.isnull(df).sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#removing null values
df = df.dropna()

# %%
df.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age            False
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin          False
# Embarked       False
# dtype: bool

# %%
df.shape
# Out:
# (183, 12)

# %%
# show some statistical details of each colunmns
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   183.000000  183.000000  183.000000  183.000000  183.000000
# mean    455.366120    0.672131    1.191257   35.674426    0.464481
# std     247.052476    0.470725    0.515187   15.643866    0.644159
# min       2.000000    0.000000    1.000000    0.920000    0.000000
# 25%     263.500000    0.000000    1.000000   24.000000    0.000000
# 50%     457.000000    1.000000    1.000000   36.000000    0.000000
# 75%     676.000000    1.000000    1.000000   47.500000    1.000000
# max     890.000000    1.000000    3.000000   80.000000    3.000000
#
#             Parch        Fare
# count  183.000000  183.000000
# mean     0.475410   78.682469
# std      0.754617   76.347843
# min      0.000000    0.000000
# 25%      0.000000   29.700000
# 50%      0.000000   57.000000
# 75%      1.000000   90.000000
# max      4.000000  512.329200

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000  0.148495 -0.089136  0.030933 -0.083488 -0.051454
# Survived        0.148495  1.000000 -0.034542 -0.254085  0.106346  0.023582
# Pclass         -0.089136 -0.034542  1.000000 -0.306514 -0.103592  0.047496
# Age             0.030933 -0.254085 -0.306514  1.000000 -0.156162 -0.271271
# SibSp          -0.083488  0.106346 -0.103592 -0.156162  1.000000  0.255346
# Parch          -0.051454  0.023582  0.047496 -0.271271  0.255346  1.000000
# Fare            0.029740  0.134241 -0.315235 -0.092424  0.286433  0.389740
#
#                  Fare
# PassengerId  0.029740
# Survived     0.134241
# Pclass      -0.315235
# Age         -0.092424
# SibSp        0.286433
# Parch        0.389740
# Fare         1.000000

# %%
# minumum and maximum age of passenger
print("Maximum age of passenger is :",df["Age"].max())
print("Minimum age of passenger is :",df["Age"].min())
# Out:
# Maximum age of passenger is : 80.0
# Minimum age of passenger is : 0.92

# %%
#passenger details having maximum age
max_age=df["Age"].max()
print(df[df["Age"]==max_age])
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 630  male  80.0      0      0  27042  30.0   A23        S

# %%
#passenger details having minimum age
min_age=df["Age"].min()
print(df[df["Age"]==min_age])
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 305          306         1       1  Allison, Master. Hudson Trevor  male
#
#       Age  SibSp  Parch  Ticket    Fare    Cabin Embarked
# 305  0.92      1      2  113781  151.55  C22 C26        S

# %%
# passenger having age 1 year or less than a year
df[df["Age"]<=1]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 183          184         1       2       Becker, Master. Richard F  male
# 305          306         1       1  Allison, Master. Hudson Trevor  male
#
#       Age  SibSp  Parch  Ticket    Fare    Cabin Embarked
# 183  1.00      2      1  230136   39.00       F4        S
# 305  0.92      1      2  113781  151.55  C22 C26        S

# %%
# show  passenger class counts
pclass_count=df["Pclass"].value_counts()
pclass_count
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
#Graphically representation of passenger class counts
plt.hist(df["Pclass"],10,density = False, facecolor = 'green')
plt.xlabel('Passenger class ')
plt.ylabel('Passenger class count')
plt.title('Histogram')
# Out:
# Text(0.5, 1.0, 'Histogram')

# %%
# pie chart of passenger class counts
pclass_count.plot.pie(autopct="%.1f%%")

# %%
#details of passcenger who has survived=1
df[df["Survived"]==1].head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 10           11         1       3
# 11           12         1       1
# 21           22         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 21                              Beesley, Mr. Lawrence    male  34.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 10      1   PP 9549  16.7000    G6        S
# 11      0    113783  26.5500  C103        S
# 21      0    248698  13.0000   D56        S

# %%
# total number of passenger who survived
scount=df["Survived"].value_counts()
scount
# Out:
# 1    123
# 0     60
# Name: Survived, dtype: int64

# %%
# pie chart of passenger according survived data
scount.plot.pie(autopct="%.1f%%")

# %%
#Graphically representation of survived passenger 
plt.hist(df["Survived"],10,density = False, facecolor = 'green')
plt.xlabel('Survived=1 and Survived=0')
plt.ylabel('Survived passenger count')
plt.title('Histogram')
# Out:
# Text(0.5, 1.0, 'Histogram')

# %%
# bar plot for survived by Pcleass
sns.barplot(x="Pclass",y="Survived",data=df)

print(" percentage of Pclass=1 who survived",df["Survived"][df["Pclass"]==1].value_counts(normalize=True)[1]*100)
print(" percentage of Pclass=2 who survived",df["Survived"][df["Pclass"]==2].value_counts(normalize=True)[1]*100)
print(" percentage of Pclass=3 who survived",df["Survived"][df["Pclass"]==3].value_counts(normalize=True)[1]*100)
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
#  percentage of Pclass=1 who survived 67.08860759493672
#  percentage of Pclass=2 who survived 80.0
#  percentage of Pclass=3 who survived 50.0

# %%
# total number of passenger according to gender
g_count=df["Sex"].value_counts()
g_count
# Out:
# male      95
# female    88
# Name: Sex, dtype: int64

# %%
#pie chart of passenger according to gender
g_count.plot.pie(autopct="%.1f%%");

# %%
# bar plot for survived by sex
sns.barplot(x="Sex",y="Survived",data=df)

print(" percentage of females who survived",df["Survived"][df["Sex"]=='female'].value_counts(normalize=True)[1]*100)
print(" percentage of males who survived",df["Survived"][df["Sex"]=='male'].value_counts(normalize=True)[1]*100)
# Out:
#  percentage of females who survived 93.18181818181817
#  percentage of males who survived 43.15789473684211

# %%
# sibsp count
sib_count=df["SibSp"].value_counts()
sib_count
# Out:
# 0    110
# 1     64
# 2      6
# 3      3
# Name: SibSp, dtype: int64

# %%
#show details of passenger who has sibsp=0
df[df["SibSp"]==0].head()
# Out:
#     PassengerId  Survived  Pclass                            Name     Sex  \
# 6             7         0       1         McCarthy, Mr. Timothy J    male
# 11           12         1       1        Bonnell, Miss. Elizabeth  female
# 21           22         1       2           Beesley, Mr. Lawrence    male
# 23           24         1       1    Sloper, Mr. William Thompson    male
# 54           55         0       1  Ostby, Mr. Engelhart Cornelius    male
#
#      Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 6   54.0      0      0   17463  51.8625   E46        S
# 11  58.0      0      0  113783  26.5500  C103        S
# 21  34.0      0      0  248698  13.0000   D56        S
# 23  28.0      0      0  113788  35.5000    A6        S
# 54  65.0      0      1  113509  61.9792   B30        C

# %%
#show details of passenger who has sibsp=0
df[df["SibSp"]==1].head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 10           11         1       3
# 52           53         1       1
# 62           63         0       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 52           Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# 62                        Harris, Mr. Henry Birkhardt    male  45.0      1
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 10      1   PP 9549  16.7000    G6        S
# 52      0  PC 17572  76.7292   D33        C
# 62      0     36973  83.4750   C83        S

# %%
# bar plot for survived by sibsp
sns.barplot(x="SibSp",y="Survived",data=df)

print(" percentage of SibSp=0 who survived",df["Survived"][df["SibSp"]==0].value_counts(normalize=True)[1]*100)
print(" percentage of SibSp=1 who survived",df["Survived"][df["SibSp"]==1].value_counts(normalize=True)[1]*100)
print(" percentage of SibSps=2 who survived",df["Survived"][df["SibSp"]==2].value_counts(normalize=True)[1]*100)
print(" percentage of SibSps=3 who survived",df["Survived"][df["SibSp"]==3].value_counts(normalize=True)[1]*100)
# Out:
#  percentage of SibSp=0 who survived 62.727272727272734
#  percentage of SibSp=1 who survived 73.4375
#  percentage of SibSps=2 who survived 83.33333333333334
#  percentage of SibSps=3 who survived 66.66666666666666

# %%
df.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 10      1   PP 9549  16.7000    G6        S
# 11      0    113783  26.5500  C103        S

# %%
df.shape
# Out:
# (183, 12)

# %%
df1 = pd.read_csv('C:/Users/lenovo/Desktop/datasets/train1.csv')
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#columwise total null values
print(pd.isnull(df).sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# replace null value by Class_3 in Cabin column
df1["Cabin"].fillna('Class_3', inplace = True)

# %%
df1["Cabin"].head(20)
# Out:
# 0     Class_3
# 1         C85
# 2     Class_3
# 3        C123
# 4     Class_3
# 5     Class_3
# 6         E46
# 7     Class_3
# 8     Class_3
# 9     Class_3
# 10         G6
# 11       C103
# 12    Class_3
# 13    Class_3
# 14    Class_3
# 15    Class_3
# 16    Class_3
# 17    Class_3
# 18    Class_3
# 19    Class_3
# Name: Cabin, dtype: object

# %%
df1["Age"].head(20)
# Out:
# 0     22.0
# 1     38.0
# 2     26.0
# 3     35.0
# 4     35.0
# 5      NaN
# 6     54.0
# 7      2.0
# 8     27.0
# 9     14.0
# 10     4.0
# 11    58.0
# 12    20.0
# 13    39.0
# 14    14.0
# 15    55.0
# 16     2.0
# 17     NaN
# 18    31.0
# 19     NaN
# Name: Age, dtype: float64

# %%
# replace null value by 00 in Age column
df1["Age"].fillna(00, inplace = True)

# %%
# value that appears most often in dataset 
print("Passcenger class value that appears most often in dataset ",df1['Pclass'].mode())
print("Gender that appears most often in dataset ",df1['Sex'].mode())
print("Age that appears most often in dataset ",df1['Age'].mode())
# Out:
# Passcenger class value that appears most often in dataset  0    3
# dtype: int64
# Gender that appears most often in dataset  0    male
# dtype: object
# Age that appears most often in dataset  0    0.0
# dtype: float64

# %%
df1.groupby(["Sex"]).count()
# Out:
#         PassengerId  Survived  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# Sex
# female          314       314     314   314  314    314    314     314   314
# male            577       577     577   577  577    577    577     577   577
#
#         Cabin  Embarked
# Sex
# female    314       312
# male      577       577

# %%
df1.groupby(["Sex"]).size()
# Out:
# Sex
# female    314
# male      577
# dtype: int64

# %%
# SURVIVED COUNT ACCORDING TO GENDER
df1.groupby(["Sex","Survived"]).size()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# dtype: int64

# %%
#pie chart showing the percentage of males that survived 
df1[df1["Sex"]=='male'].groupby(["Sex","Survived"]).size().plot.pie(autopct="%.1f%%")

# %%
#pie chart showing the percentage of females that survived 
df1[df1["Sex"]=='female'].groupby(["Sex","Survived"]).size().plot.pie(autopct="%.1f%%")

# %%
# passenger cabin number
df1["Cabin"].unique()
# Out:
# array(['Class_3', 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df1.groupby(["Cabin"]).mean()
# Out:
#        PassengerId  Survived  Pclass        Age     SibSp     Parch  \
# Cabin
# A10          584.0  0.000000     1.0  36.000000  0.000000  0.000000
# A14          476.0  0.000000     1.0   0.000000  0.000000  0.000000
# A16          557.0  1.000000     1.0  48.000000  1.000000  0.000000
# A19          285.0  0.000000     1.0   0.000000  0.000000  0.000000
# A20          600.0  1.000000     1.0  49.000000  1.000000  0.000000
# A23          631.0  1.000000     1.0  80.000000  0.000000  0.000000
# A24          868.0  0.000000     1.0  31.000000  0.000000  0.000000
# A26          648.0  1.000000     1.0  56.000000  0.000000  0.000000
# A31          210.0  1.000000     1.0  40.000000  0.000000  0.000000
# A32          186.0  0.000000     1.0   0.000000  0.000000  0.000000
# A34          446.0  1.000000     1.0   4.000000  0.000000  2.000000
# A36          807.0  0.000000     1.0  39.000000  0.000000  0.000000
# A5            97.0  0.000000     1.0  71.000000  0.000000  0.000000
# ...

# %%
# finding passenger details by it's passenger ID
ID=int(input("Enter ID to find Passenger details:"))
df1[df1["PassengerId"]==ID]
# Out:
# Enter ID to find Passenger details:773
#      PassengerId  Survived  Pclass               Name     Sex   Age  SibSp  \
# 772          773         0       2  Mack, Mrs. (Mary)  female  57.0      0
#
#      Parch       Ticket  Fare Cabin Embarked
# 772      0  S.O./P.P. 3  10.5   E77        S

# %%
# Cabin number by Fare 
df1.groupby(["Fare","Cabin"]).size()
# Out:
# Fare      Cabin
# 0.0000    A36                 1
#           B102                1
#           B94                 1
#           Class_3            12
# 4.0125    Class_3             1
# 5.0000    B51 B53 B55         1
# 6.2375    Class_3             1
# 6.4375    Class_3             1
# 6.4500    Class_3             1
# 6.4958    Class_3             2
# 6.7500    Class_3             2
# 6.8583    Class_3             1
# 6.9500    Class_3             1
# 6.9750    Class_3             2
# 7.0458    Class_3             1
# 7.0500    Class_3             7
# 7.0542    Class_3             2
# 7.1250    Class_3             4
# 7.1417    Class_3             1
# 7.2250    Class_3            12
# 7.2292    Class_3            15
# 7.2500    Class_3            13
# 7.3125    Class_3             1
# 7.4958    Class_3             3
# 7.5208    Class_3             1
# 7.5500    Class_3             4
# 7.6292    Class_3             1
# 7.6500    Class_3             1
# ...

# %%
# total Cabin count by pclass
cabin_count=df1[["Pclass","Cabin"]].groupby("Pclass").count()
cabin_count
# Out:
#         Cabin
# Pclass
# 1         216
# 2         184
# 3         491

# %%
# Graphically representation of total Cabin count by pclass(pie chart)
df1[["Cabin","Pclass"]].groupby(["Pclass"]).size().plot.pie(autopct="%.1f%%")

# %%
# Graphically representation of total Cabin count by pclass(bar graph)
df1[["Cabin","Pclass"]].groupby(["Pclass"]).size().plot.bar()
